# %% [markdown]
# ## Student name: Fahima Hyder
# ## Student pace: part time
# ## Scheduled project review date/time: August 16, 2019, 530 pm
# ## Blog URL: https://fhyder.github.io/a_game_of_classification_models
# ## Instructor name: Jeff Herman

# %%
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import tree 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.preprocessing import StandardScaler, label_binarize, LabelEncoder
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import matplotlib.pyplot as plt
import numpy as np
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from ann_visualizer.visualize import ann_viz
np.random.seed(0)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # First, load the csv file into a dataframe

# %%
# %%time 
df = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB
# CPU times: user 1.41 s, sys: 183 ms, total: 1.59 s
# Wall time: 1.68 s

# %% [markdown]
# #### Country: The country that the wine is from
# #### Description: Description of wine by Sommeliers
# #### Taster_name: Sommelier name
# #### Taster_twitter_handle: Taster twitter handle
# #### Designation:The vineyard within the winery where the grapes that made the wine are from
# #### Winery: The winery that made the wine
# #### Points: The number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews for wines that score >=80)
# #### Province: The province or state that the wine is from
# #### Region_1: The wine growing area in a province or state (ie Napa)
# #### Region_2: Sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this value can sometimes be blank
# #### Title: The title of the wine
# #### Variety: The type of grapes used to make the wine (ie Pinot Noir)
# #### Price: The cost for a bottle of the wine (target variable)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
df.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df.variety.value_counts(normalize = True)
# Out:
# Pinot Noir                    0.102116
# Chardonnay                    0.090429
# Cabernet Sauvignon            0.072878
# Red Blend                     0.068831
# Bordeaux-style Red Blend      0.053205
# Riesling                      0.039925
# Sauvignon Blanc               0.038217
# Syrah                         0.031869
# Rosé                          0.027422
# Merlot                        0.023867
# Nebbiolo                      0.021574
# Zinfandel                     0.020882
# Sangiovese                    0.020828
# Malbec                        0.020405
# Portuguese Red                0.018974
# White Blend                   0.018158
# Sparkling Blend               0.016565
# Tempranillo                   0.013926
# Rhône-style Red Blend         0.011318
# Pinot Gris                    0.011195
# Champagne Blend               0.010741
# Cabernet Franc                0.010410
# Grüner Veltliner              0.010349
# Portuguese White              0.008917
# Bordeaux-style White Blend    0.008202
# Pinot Grigio                  0.008094
# Gamay                         0.007886
# Gewürztraminer                0.007786
# Viognier                      0.007663
# Shiraz                        0.006432
#                                 ...
# Forcallà                      0.000008
# Sauvignon-Sémillon            0.000008
# Trajadura                     0.000008
# Irsai Oliver                  0.000008
# Carcajolu                     0.000008
# Moschofilero-Chardonnay       0.000008
# Jampal                        0.000008
# Moscato di Noto               0.000008
# Dafni                         0.000008
# Malagouzia-Chardonnay         0.000008
# Sauvignon Blanc-Assyrtiko     0.000008
# Colorino                      0.000008
# Caprettone                    0.000008
# Frankovka                     0.000008
# Franconia                     0.000008
# Cabernet-Malbec               0.000008
# Riesling-Chardonnay           0.000008
# Barbera-Nebbiolo              0.000008
# Tintilia                      0.000008
# Roscetto                      0.000008
# Orangetraube                  0.000008
# Favorita                      0.000008
# Misket                        0.000008
# Malbec-Carménère              0.000008
# Cabernet Sauvignon-Barbera    0.000008
# Vespaiolo                     0.000008
# Valvin Muscat                 0.000008
# Prunelard                     0.000008
# País                          0.000008
# Ramisco                       0.000008
# Name: variety, Length: 707, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB

# %%
df.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df.drop(['region_2', 'designation', 'taster_name', 'taster_twitter_handle', 'region_1'], axis = 1, inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120915 entries, 1 to 129970
# Data columns (total 8 columns):
# country        120915 non-null object
# description    120915 non-null object
# points         120915 non-null int64
# price          120915 non-null float64
# province       120915 non-null object
# title          120915 non-null object
# variety        120915 non-null object
# winery         120915 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 8.3+ MB

# %%
df.variety.nunique()
# Out:
# 691

# %%
df.variety.unique()
# Out:
# array(['Portuguese Red', 'Pinot Gris', 'Riesling', 'Pinot Noir',
#        'Tempranillo-Merlot', 'Frappato', 'Gewürztraminer',
#        'Cabernet Sauvignon', 'Chardonnay', 'Malbec', 'Tempranillo Blend',
#        'Meritage', 'Red Blend', 'White Blend', 'Merlot', "Nero d'Avola",
#        'Chenin Blanc', 'Sauvignon Blanc', 'Viognier-Chardonnay',
#        'Primitivo', 'Catarratto', 'Gamay', 'Inzolia', 'Petit Verdot',
#        'Monica', 'Bordeaux-style White Blend', 'Grillo', 'Sangiovese',
#        'Cabernet Franc', 'Champagne Blend', 'Bordeaux-style Red Blend',
#        'Aglianico', 'Petite Sirah', 'Carmenère', 'Albariño',
#        'Petit Manseng', 'Rosé', 'Zinfandel', 'Vernaccia', 'Rosato',
#        'Grüner Veltliner', 'Viognier', 'Vermentino', 'Grenache Blanc',
#        'Syrah', 'Nebbiolo', 'Shiraz-Cabernet Sauvignon', 'Pinot Blanc',
#        'Alsace white blend', 'Barbera', 'Rhône-style Red Blend',
#        'Portuguese White', 'Graciano', 'Tannat-Cabernet', 'Sauvignon',
#        'Torrontés', 'Prugnolo Gentile', 'G-S-M', 'Verdejo', 'Fumé Blanc',
#        'Furmint', 'Pinot Bianco', 'Bonarda', 'Shiraz', 'Montepulciano',
#        'Moscato', 'Grenache', 'Ugni Blanc-Colombard', 'Syrah-Viognier',
#        'Blaufränkisch', 'Friulano', 'Assyrtico', 'Carignan-Grenache',
#        'Savagnin', 'Cabernet Sauvignon-Syrah', 'Prosecco', 'Vignoles',
#        'Sparkling Blend', 'Muscat', 'Muscadelle', 'Shiraz-Viognier',
#        'Garganega', 'Pinot Grigio', 'Tempranillo', 'Cortese', 'Mencía',
#        'Zweigelt', 'Nerello Mascalese', 'Melon',
#        'Rhône-style White Blend', 'Vidal', 'Cannonau', 'Verdelho',
#        'Marsanne', 'Scheurebe', 'Kerner', 'Syrah-Grenache', 'Dolcetto',
#        'Vilana', 'Glera', 'Viura', 'Garnacha Tintorera', 'Pinot Nero',
#        'Pinotage', 'Sémillon', 'Pinot Noir-Gamay', 'Antão Vaz',
#        'Cabernet Sauvignon-Carmenère', 'Verdejo-Viura', 'Verduzzo',
#        'Verdicchio', 'Silvaner', 'Colombard', 'Carricante', 'Sylvaner',
#        'Fiano', 'Früburgunder', 'Sousão', 'Roussanne', 'Avesso',
#        'Cinsault', 'Tinta Miúda', 'Muscat Blanc à Petits Grains',
#        'Portuguese Sparkling', 'Monastrell', 'Xarel-lo', 'Greco',
#        'Trebbiano', 'Corvina, Rondinella, Molinara',
#        'Chenin Blanc-Chardonnay', 'Insolia', 'Merlot-Malbec',
#        'Ribolla Gialla', 'Cabernet Sauvignon-Merlot', 'Port',
#        'Weissburgunder', 'Roditis', 'Traminer', 'Papaskarasi',
#        'Tannat-Syrah', 'Marsanne-Roussanne', 'Charbono',
#        'Sangiovese Grosso', 'Merlot-Argaman', 'Prié Blanc', 'Sherry',
#        'Provence red blend', 'Zibibbo', 'Falanghina', 'Garnacha',
#        'Negroamaro', 'Mourvèdre', 'Syrah-Cabernet', 'Müller-Thurgau',
#        'Pinot Meunier', 'Cabernet Sauvignon-Sangiovese',
#        'Austrian Red Blend', 'Teroldego', 'Sagrantino', 'Tannat',
#        'Pansa Blanca', 'Muskat Ottonel', 'Sauvignon Blanc-Semillon',
#        'Claret', 'Semillon-Sauvignon Blanc', 'Bical', 'Touriga Nacional',
#        'Moscatel', 'Rosado', 'Viura-Chardonnay', 'Baga',
#        'Malvasia Bianca', 'Gelber Muskateller', 'Malbec-Merlot',
#        'Monastrell-Syrah', 'Malbec-Tannat', 'Malbec-Cabernet Franc',
#        'Refosco', 'Turbiana', 'Alvarinho', 'Agiorgitiko', 'Malagousia',
#        'Assyrtiko', 'Ruché', 'Welschriesling', 'Tinta de Toro',
#        'Cabernet Moravia', 'Rieslaner', 'Traminette', 'Chambourcin',
#        'Lambrusco di Sorbara', 'Cesanese', 'Feteasca Neagra', 'Lagrein',
#        'Tinta Fina', 'St. Laurent', 'Marsanne-Viognier',
#        'Cabernet Sauvignon-Shiraz', 'Syrah-Cabernet Sauvignon',
#        'Gewürztraminer-Riesling', 'Pugnitello', 'Cerceal',
#        'Touriga Nacional Blend', 'Tocai', 'Fernão Pires',
#        'Cabernet Franc-Cabernet Sauvignon', 'Grenache-Syrah',
#        'Seyval Blanc', 'Muscat Canelli', 'Cabernet Merlot',
#        'Tempranillo-Cabernet Sauvignon', 'Arinto',
#        'Merlot-Cabernet Franc', 'Syrah-Petite Sirah', 'Cabernet Blend',
#        'Maturana', 'Pecorino', 'Rotgipfler', 'Kinali Yapincak',
#        'Cabernet Franc-Carmenère', 'Gamay Noir', 'Sauvignon Gris',
#        'Spätburgunder', 'Picpoul', 'Vidal Blanc', 'Albanello', 'Arneis',
#        'Malvasia', 'Plavac Mali', 'Lemberger', 'Saperavi', 'Altesse',
#        'Blanc du Bois', 'Provence white blend', 'Nosiola', 'Dornfelder',
#        'Roussanne-Viognier', 'Godello', 'Mondeuse', 'Perricone',
#        'Pedro Ximénez', 'Auxerrois', 'Syrah-Merlot', 'Albana', 'Muskat',
#        'Lambrusco', 'Cabernet Sauvignon-Malbec', 'Tinto Fino',
#        'Malbec-Cabernet Sauvignon', 'Moschofilero', 'Grechetto',
#        'Encruzado', 'Carignano', 'Cabernet Franc-Merlot', 'Torbato',
#        'Syrah-Petit Verdot', 'Garnacha Blanca', 'Pallagrello', 'Morava',
#        'Syrah-Mourvèdre', 'Aleatico', 'Carcajolu', 'Kisi', 'Zierfandler',
#        'Shiraz-Grenache', 'Palomino', 'Magliocco', 'Grenache-Carignan',
#        'Nascetta', 'Siria', 'Malbec-Syrah', 'Feteascǎ Regalǎ',
#        'Lambrusco Grasparossa', 'Marselan', 'Tocai Friulano', 'Schiava',
#        'Alfrocheiro', 'Chardonnay-Semillon', 'Norton',
#        'Alicante Bouschet', 'Tokaji', 'Moscadello',
#        'Cabernet Sauvignon-Tempranillo', 'Carignan', 'Loureiro-Arinto',
#        'Cabernet-Syrah', 'Sauvignon Blanc-Chardonnay', 'Symphony',
#        'Edelzwicker', 'Black Muscat', 'Grenache Noir', 'Durella',
#        'Xinomavro', 'Tinto del Pais', 'Merlot-Cabernet Sauvignon',
#        'Cercial', 'Roter Veltliner', 'Johannisberg Riesling',
#        'Petite Verdot', 'Passerina', 'Valdiguié',
#        'Colombard-Sauvignon Blanc', 'Kangoun', 'Loureiro', 'Posip',
#        'Uva di Troia', 'Gros and Petit Manseng', 'Jacquère',
#        'Kalecik Karasi', 'Karasakiz', 'Mourvèdre-Syrah', 'Negrette',
#        'Zierfandler-Rotgipfler', 'Clairette', 'Aragonez', 'Raboso',
#        'País', 'Chardonnay-Viognier', 'Mauzac', 'Pinot Auxerrois',
#        'Chenin Blanc-Sauvignon Blanc', 'Diamond', 'Marzemino',
#        'Tinta Barroca', 'Chardonnay-Sauvignon Blanc', 'Castelão',
#        'Trebbiano Spoletino', 'Teran', 'Trepat', 'Freisa', 'Neuburger',
#        'Nero di Troia', 'Chasselas', 'Tinta Roriz', 'Hárslevelü',
#        'Trincadeira', 'Merlot-Tannat', 'Rkatsiteli', 'Siegerrebe',
#        'Trousseau Gris', 'Grenache Blend', 'Austrian white blend',
#        'Gros Manseng', 'Portuguese Rosé', 'Brachetto', 'Muskateller',
#        'Aligoté', 'Sangiovese Cabernet',
#        'Touriga Nacional-Cabernet Sauvignon', 'Muscat Blanc', 'Argaman',
#        'Viognier-Roussanne', 'Pallagrello Bianco', 'Bobal',
#        'Malvasia Istriana', 'Cabernet Sauvignon-Cabernet Franc',
#        'Baco Noir', 'Veltliner', 'Tempranillo-Tannat', 'Morillon',
#        'Touriga Franca', 'Barbera-Nebbiolo', 'Prieto Picudo', 'Gaglioppo',
#        'Tokay', 'Piedirosso', 'Piquepoul Blanc', 'Chardonnay-Sauvignon',
#        'Tempranillo-Garnacha', 'Carmenère-Cabernet Sauvignon',
#        'Chenin Blanc-Viognier', 'Susumaniello', 'Vitovska',
#        'Orange Muscat', 'Grauburgunder', 'Carignane', 'Moscatel Roxo',
#        'Picolit', 'Nerello Cappuccio', 'Counoise', 'Macabeo', 'Mazuelo',
#        'Sauvignon-Sémillon', 'Tinta del Pais', 'Vranec', 'Corvina',
#        'Mavrud', "Cesanese d'Affile", 'Moscato Giallo', 'Debit', 'Verdil',
#        'Cabernet', 'Verduzzo Friulano ', 'Treixadura', 'Duras',
#        "Loin de l'Oeil", 'Coda di Volpe', 'Grenache-Mourvèdre',
#        'Forcallà', 'Viura-Verdejo', 'Manzoni', 'Pinot-Chardonnay',
#        'Syrah-Tempranillo', 'Cabernet Sauvignon-Barbera',
#        'Merlot-Cabernet', "Muscat d'Alexandrie", 'Jaen', 'Tinta del Toro',
#        'Timorasso', 'Pigato', 'Sangiovese-Cabernet Sauvignon',
#        'Shiraz-Cabernet', 'Viognier-Gewürztraminer', 'Prunelard',
#        'Sauvignon Blanc-Chenin Blanc', 'Gros Plant',
#        'Malbec-Petit Verdot', 'Colombard-Ugni Blanc', 'Sacy', 'Mansois',
#        'Grignolino', 'Garnacha-Syrah', 'Rufete', 'Tempranillo-Shiraz',
#        'Mtsvane', 'Chardonnay-Pinot Gris', 'Marawi',
#        'Chardonnay-Pinot Blanc', 'Mataro', 'Tinta Cao',
#        'Blauer Portugieser', 'Ugni Blanc', 'Groppello',
#        'Semillon-Chardonnay', 'Irsai Oliver', 'Alvarelhão', 'Poulsard',
#        'Grenache-Shiraz', 'Baga-Touriga Nacional', 'Carineña',
#        'Pignoletto', 'Muscatel', 'Mavrodaphne', 'Ciliegiolo', 'Mantonico',
#        'Viognier-Grenache Blanc', 'Cabernet Sauvignon-Merlot-Shiraz',
#        'Sciaccerellu', 'Alicante', 'Emir', 'Rosenmuskateller', 'Narince',
#        'Malbec-Cabernet', 'Touriga', 'Grecanico', 'Carmenère-Syrah',
#        'Madeleine Angevine', 'Mavroudi', 'Pinot Blanc-Pinot Noir',
#        'Muscat Hamburg', 'Tempranillo Blanco', 'Aragonês', 'Casavecchia',
#        'Pinot Gris-Gewürztraminer', 'White Riesling', 'Tinto Velasco',
#        'Hondarrabi Zuri', 'Nuragus', 'Xynisteri', 'Kadarka',
#        'Sauvignon Musqué', 'Roussanne-Marsanne', 'Incrocio Manzoni',
#        'Terrantez', 'Bual', 'Okuzgozu', 'Rivaner', 'Doña Blanca',
#        'Graševina', 'Lambrusco Salamino', 'Sangiovese-Syrah',
#        'Tannat-Cabernet Franc', 'Thrapsathiri', 'Fer Servadou', 'Mission',
#        'Kekfrankos', 'Cococciola', 'Blauburgunder', 'Tannat-Merlot',
#        'Marquette', 'Romorantin', 'Bombino Bianco',
#        'Verdejo-Sauvignon Blanc', 'Braucol', 'Malvasia-Viura',
#        'Savatiano', 'Cabernet Franc-Malbec', 'Pallagrello Nero', 'Rebula',
#        'Vespolina', 'Shiraz-Malbec', 'Rebo', 'Macabeo-Chardonnay',
#        'Tamjanika', 'Chinuri', 'Trousseau', 'Syrah-Malbec',
#        'Syrah-Cabernet Franc', 'Macabeo-Moscatel', 'Cariñena-Garnacha',
#        'Plyto', 'Códega do Larinho', 'Sideritis', 'Çalkarası', 'Azal',
#        'Moscatel Graúdo', 'Viosinho', 'Moschofilero-Chardonnay',
#        'Paralleda', 'Rara Neagra', 'Malvasia di Candia', 'Maria Gomes',
#        'Molinara', 'Malvar', 'Airen', 'Erbaluce', 'Muscat of Alexandria',
#        'Verdosilla', 'Abouriou', 'Pinot Noir-Syrah', 'Nielluciu',
#        'Malbec-Bonarda', 'Vespaiolo', 'Malbec-Carménère', 'Biancolella',
#        'Sauvignon Blanc-Verdejo', 'Aidani', 'Garnacha-Monastrell',
#        'Greco Bianco', 'Vinhão', 'Souzao', 'Roter Traminer',
#        'Moscatel de Alejandría', 'White Port', 'Rolle', 'Tinta Francisca',
#        'Malvasia Nera', 'Orangetraube', 'Riesling-Chardonnay', 'Žilavka',
#        'Portuguiser', 'Listán Negro', 'Pinotage-Merlot', 'Muscadine',
#        'Maria Gomes-Bical', 'Grolleau', 'Zlahtina',
#        'Syrah-Grenache-Viognier', 'Jacquez', 'Gouveio', 'Canaiolo',
#        'Carignan-Syrah', 'Bombino Nero', 'Chardonnay-Riesling',
#        'Malagouzia-Chardonnay', 'Mavrotragano', 'Bovale', 'Frankovka',
#        'Shiraz-Roussanne', 'Cabernet-Shiraz', 'Syrah-Carignan', 'Elbling',
#        'Gragnano', 'Garnacha Blend', 'Pinot Blanc-Chardonnay',
#        'Schwartzriesling', 'Bastardo', 'Vidadillo', 'Misket',
#        'Chardonnay Weissburgunder', 'Other', 'Robola', 'Merlot-Shiraz',
#        'Malagouzia', 'Sämling', 'Folle Blanche', 'Malbec Blend',
#        'Merlot-Syrah', 'Tamianka', 'Cabernet Pfeffer', 'Morio Muskat',
#        'Rabigato', 'Babić', 'Yapincak', 'Sauvignonasse',
#        'Viognier-Marsanne', 'Mandilaria', 'Meseguera',
#        'Alvarinho-Chardonnay', 'Saperavi-Merlot', 'Pinot Blanc-Viognier',
#        'Teroldego Rotaliano', 'Garnacha-Tempranillo', 'Xinisteri',
#        'Trebbiano di Lugana', 'Albarossa', 'Ryzlink Rýnský', 'Verdeca',
#        'Cabernet Sauvignon Grenache', 'Tămâioasă Românească',
#        'Black Monukka', 'Merlot-Grenache', 'Tempranillo-Syrah',
#        'Chardonel', 'Silvaner-Traminer', 'Madeira Blend', 'Uvalino',
#        'Merseguera-Sauvignon Blanc', 'Cabernet-Malbec', 'Boğazkere',
#        'Gelber Traminer', 'Vermentino Nero', 'Cayuga', 'Tinta Amarela',
#        'Tinta Negra Mole', 'Moscato Rosa', 'Chelois',
#        'Sauvignon Blanc-Assyrtiko', 'Muscadel', 'Shiraz-Tempranillo',
#        'Roussanne-Grenache Blanc', 'Biancale', 'Ansonica',
#        'Syrah-Bonarda', 'Durif', 'Roviello', 'Franconia',
#        'Malbec-Tempranillo', 'Nasco', 'Monastrell-Petit Verdot', 'Sirica',
#        'Apple', 'Pinot Grigio-Sauvignon Blanc', 'Blatina', 'Karalahna',
#        'Feteasca', 'Sercial', 'Valvin Muscat', 'Malvasia Fina',
#        'Roditis-Moschofilero', 'St. Vincent', 'Chancellor', 'Premsal',
#        'Jampal', 'Tokay Pinot Gris', 'Colorino', 'Picapoll', 'Blauburger',
#        'Tinta Madeira', 'Centesimino', 'Grenache Gris', 'Trajadura',
#        'Merlot-Petite Verdot', 'Ramisco', 'Catalanesca',
#        'Garnacha-Cabernet', 'Garnacha-Cariñena', 'Gamza',
#        'Cabernet Franc-Lemberger', 'Chardonnay-Albariño',
#        'Shiraz-Mourvèdre', 'Mavrokalavryta', 'Favorita', 'Babosa Negro',
#        'Tintilia ', 'Dafni', 'Petit Courbu', 'Kotsifali', 'Parraleta',
#        'Moscato di Noto', 'Torontel', 'Viognier-Valdiguié', 'Trollinger',
#        'Francisa', 'Kuntra', 'Pignolo', 'Asprinio', 'Caprettone',
#        'Ondenc', 'Athiri', 'Bobal-Cabernet Sauvignon'], dtype=object)

# %%
df.variety.value_counts(normalize = True)
# Out:
# Pinot Noir                  0.105735
# Chardonnay                  0.197345
# Cabernet Sauvignon          0.274953
# Red Blend                   0.344970
# Bordeaux-style Red Blend    0.389133
# Riesling                    0.430244
# Sauvignon Blanc             0.469776
# Syrah                       0.503569
# Rosé                        0.530538
# Merlot                      0.555853
# Zinfandel                   0.578249
# Malbec                      0.599694
# Sangiovese                  0.619352
# Nebbiolo                    0.638630
# Portuguese Red              0.656792
# White Blend                 0.674714
# Sparkling Blend             0.691477
# Tempranillo                 0.706265
# Rhône-style Red Blend       0.717876
# Pinot Gris                  0.729355
# Cabernet Franc              0.740140
# Champagne Blend             0.750155
# Grüner Veltliner            0.759625
# Pinot Grigio                0.767911
# Portuguese White            0.776066
# Viognier                    0.784212
# Gewürztraminer              0.792110
# Gamay                       0.799024
# Shiraz                      0.805814
# Petite Sirah                0.812166
#                               ...
# Merlot-Shiraz               0.999760
# Verdosilla                  0.999768
# Jampal                      0.999777
# Carcajolu                   0.999785
# Syrah-Grenache-Viognier     0.999793
# Thrapsathiri                0.999802
# Gros Plant                  0.999810
# Ondenc                      0.999818
# Blauburgunder               0.999826
# Kotsifali                   0.999835
# Dafni                       0.999843
# Paralleda                   0.999851
# Tempranillo-Tannat          0.999859
# Loureiro-Arinto             0.999868
# Folle Blanche               0.999876
# Biancale                    0.999884
# Žilavka                     0.999892
# Cercial                     0.999901
# Biancolella                 0.999909
# Premsal                     0.999917
# Torontel                    0.999926
# White Port                  0.999934
# Molinara                    0.999942
# Verdil                      0.999950
# Xinisteri                   0.999959
# Maria Gomes-Bical           0.999967
# Picapoll                    0.999975
# Cococciola                  0.999983
# Bombino Bianco              0.999992
# Ryzlink Rýnský              1.000000
# Name: variety, Length: 691, dtype: float64

# %%
x = df.variety.value_counts(normalize = True)#trying to isolate the grapes that make up approx 90% of the dataset

# %%
y = []
for i in list(range(0,60)):
    y.append(x[i])
#isolate top

# %%
sum(y) #eureka!
# Out:
# 0.9068684613158002

# %%
z = df.variety.value_counts().keys().tolist()
grapes = []
for i in list(range(0,60)):
    grapes.append(z[i])

# %%
len(y) == len(grapes) ## sanity check
# Out:
# True

# %%
df = df[df['variety'].isin(grapes)]

# %%
df.variety.nunique() #sanity check
# Out:
# 60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109654 entries, 1 to 129970
# Data columns (total 8 columns):
# country        109654 non-null object
# description    109654 non-null object
# points         109654 non-null int64
# price          109654 non-null float64
# province       109654 non-null object
# title          109654 non-null object
# variety        109654 non-null object
# winery         109654 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 7.5+ MB

# %%
df.country.nunique(), df.province.nunique(), df.title.nunique(), df.winery.nunique()
# Out:
# (40, 370, 100301, 15051)

# %%
df.province.value_counts(normalize = True)
# Out:
# California             0.317344
# Washington             0.074571
# Oregon                 0.047531
# Tuscany                0.044750
# Bordeaux               0.036332
# Burgundy               0.028015
# Mendoza Province       0.026985
# Northern Spain         0.026182
# Piedmont               0.025325
# New York               0.023054
# Veneto                 0.020464
# Alsace                 0.018330
# Loire Valley           0.014154
# Champagne              0.012457
# Northeastern Italy     0.011664
# South Australia        0.010934
# Sicily & Sardinia      0.009667
# Douro                  0.009484
# Provence               0.009421
# Mosel                  0.009238
# Catalonia              0.009229
# Rhône Valley           0.008855
# Southwest France       0.008718
# Beaujolais             0.007697
# Marlborough            0.007159
# Colchagua Valley       0.007132
# Alentejano             0.006457
# Virginia               0.006174
# Central Italy          0.005554
# Maipo Valley           0.005545
#                          ...
# Breede River Valley    0.000009
# Elazığ-Diyarbakir      0.000009
# Szekszárd              0.000009
# Serra do Sudeste       0.000009
# Viile Timis            0.000009
# Vlootenburg            0.000009
# Codru Region           0.000009
# Urla-Thrace            0.000009
# Panciu                 0.000009
# Mantinia               0.000009
# Waitaki Valley         0.000009
# Neuchâtel              0.000009
# Hawaii                 0.000009
# Alenteo                0.000009
# Breedekloof            0.000009
# Patras                 0.000009
# Pitsilia Mountains     0.000009
# Vinho Espumante        0.000009
# Requinoa               0.000009
# Lutzville Valley       0.000009
# Table wine             0.000009
# Elim                   0.000009
# Württemberg            0.000009
# Gladstone              0.000009
# Cyclades               0.000009
# Cape South Coast       0.000009
# Sopron                 0.000009
# Kathikas               0.000009
# Armenia                0.000009
# Paardeberg             0.000009
# Name: province, Length: 370, dtype: float64

# %%
province_counts = df.province.value_counts(normalize=True).tolist() #again shooting for approx 90%

# %%
topfifty = []
for x in list(range(0,50)):
    topfifty.append(province_counts[x])

# %%
len(topfifty)
# Out:
# 50

# %%
sum(topfifty)
# Out:
# 0.9223010560490267

# %%
prov = df.province.value_counts().keys().tolist()

# %%
provinces = []
for x in list(range(0,50)):
    provinces.append(prov[x])

# %%
df = df[df['province'].isin(provinces)]

# %%
df.head()
# Out:
#     country                                        description  points  price  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
# 7    France  This dry and restrained wine offers spice in p...      87   24.0
# 9    France  This has great depth of flavor with its fresh ...      87   27.0
#
#   province                                              title         variety  \
# 1    Douro      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2   Oregon      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 4   Oregon  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# 7   Alsace              Trimbach 2012 Gewurztraminer (Alsace)  Gewürztraminer
# 9   Alsace  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...      Pinot Gris
#
#                 winery
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 4         Sweet Cheeks
# 7             Trimbach
# 9   Jean-Baptiste Adam

# %%
df.province.nunique()
# Out:
# 50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Data columns (total 8 columns):
# country        101134 non-null object
# description    101134 non-null object
# points         101134 non-null int64
# price          101134 non-null float64
# province       101134 non-null object
# title          101134 non-null object
# variety        101134 non-null object
# winery         101134 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.9+ MB

# %%
df.winery.nunique()
# Out:
# 13706

# %%
winess = df.winery.value_counts(normalize=True).tolist()

# %%
wineries = []
for i in list(range(0,50)):
    wineries.append(winess[i])
sum(wineries)
# Out:
# 0.05260347657563234

# %%
wineries = []
for i in list(range(0,100)):
    wineries.append(winess[i])
sum(wineries) #way too many wineries, too many observations
# Out:
# 0.08855577748333894

# %%
df.title.nunique() #feel like almost every wine will have a diff name
# Out:
# 92449

# %%
df.title.value_counts(normalize = True) #drop this, too many observations
# Out:
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma County)                          0.000109
# Korbel NV Brut Sparkling (California)                                           0.000089
# Segura Viudas NV Extra Dry Sparkling (Cava)                                     0.000079
# Segura Viudas NV Aria Estate Extra Dry Sparkling (Cava)                         0.000069
# Gloria Ferrer NV Blanc de Noirs Sparkling (Carneros)                            0.000069
# Ruinart NV Brut Rosé  (Champagne)                                               0.000069
# Korbel NV Sweet Rosé Sparkling (California)                                     0.000059
# Bailly-Lapierre NV Brut  (Crémant de Bourgogne)                                 0.000059
# J Vineyards & Winery NV Brut Rosé Sparkling (Russian River Valley)              0.000059
# Mumm Napa NV Brut Prestige Sparkling (Napa Valley)                              0.000059
# Boizel NV Brut Réserve  (Champagne)                                             0.000059
# Chandon NV Rosé Sparkling (California)                                          0.000049
# Roederer Estate NV Brut Rosé Sparkling (Anderson Valley)                        0.000049
# Mumm Napa NV Cuvée M Sparkling (Napa Valley)                                    0.000049
# J. Dumangin Fils NV Le Rosé Premier Cru Brut  (Champagne)                       0.000049
# Breathless NV Brut Sparkling (North Coast)                                      0.000049
# Pierre Sparr NV Brut Réserve Sparkling (Crémant d'Alsace)                       0.000049
# Freixenet NV Cordon Negro Brut Sparkling (Cava)                                 0.000049
# Pommery NV Brut Royal  (Champagne)                                              0.000049
# Jean Laurent NV Blanc de Noirs Brut Pinot Noir (Champagne)                      0.000049
# Henri Abele NV Brut  (Champagne)                                                0.000049
# Jacquart NV Brut Mosaïque  (Champagne)                                          0.000049
# Segura Viudas NV Reserva Heredad Sparkling (Cava)                               0.000049
# Korbel NV Blanc de Noirs Sparkling (California)                                 0.000049
# Freixenet NV Cordon Negro Extra Dry Sparkling (Cava)                            0.000049
# Korbel NV Extra Dry Sparkling (California)                                      0.000040
# Masottina NV Brut  (Conegliano Valdobbiadene Prosecco Superiore)                0.000040
# Louis Roederer NV Brut Premier  (Champagne)                                     0.000040
# Segura Viudas NV Aria Estate Brut Sparkling (Cava)                              0.000040
# Segura Viudas NV Brut Reserva Sparkling (Cava)                                  0.000040
#                                                                                   ...
# Joseph Swan Vineyards 2008 Trenton Station Pinot Gris (Russian River Valley)    0.000010
# Patterson 2011 Cabernet Sauvignon (Columbia Valley (WA))                        0.000010
# Silvan Ridge 2001 Chardonnay (Oregon)                                           0.000010
# Chateau Ste. Michelle 2006 Indian Wells Chardonnay (Columbia Valley (WA))       0.000010
# Julietta 2012 Reserve Cabernet Sauvignon (Stags Leap District)                  0.000010
# Château La Croix de Queynac 2015 Rosé (Bordeaux Rosé)                           0.000010
# Lava Cap 2014 Vinehill Viognier (El Dorado)                                     0.000010
# StoneCap 2011 Estate Grown Cabernet Sauvignon (Columbia Valley (WA))            0.000010
# Bergström 2013 Bergström Vineyard Pinot Noir (Dundee Hills)                     0.000010
# Charles Ellner NV Rosé Brut  (Champagne)                                        0.000010
# Les Rocailles NV Caprice des Rocailles Gamay (Savoie)                           0.000010
# Lenz Moser 2014 Grüner Veltliner (Niederösterreich)                             0.000010
# Terre Rouge 2014 Enigma White (Sierra Foothills)                                0.000010
# Sepp Moser 2014 Von den Terrassen Riesling (Kremstal)                           0.000010
# Terrazas de Los Andes 2006 Reserva Malbec (Mendoza)                             0.000010
# Château de la Tour 2013  Clos de Vougeot                                        0.000010
# Stolo 2015 Estate Rosé of Pinot Noir (San Luis Obispo County)                   0.000010
# Victor Vineyards 2013 Cabernet Sauvignon (Lodi)                                 0.000010
# Love Noir 2012 Pinot Noir (California)                                          0.000010
# Quinta de Ventozelo 2009 Tinto Red (Douro)                                      0.000010
# Patient Cottat 2012 Le Grand Caillou Pinot Noir (Vin de France)                 0.000010
# Joseph Drouhin 2014 Domaine des Hospices de Belleville  (Fleurie)               0.000010
# Kenwood 2011 Cabernet Sauvignon (Sonoma County)                                 0.000010
# Georges Vigouroux 2009 Cuvée Icône du Château de Mercuès Malbec (Cahors)        0.000010
# EnRoute 2010 Les Pommiers Pinot Noir (Russian River Valley)                     0.000010
# Calstar Cellars 2014 Sauvignon Blanc (Russian River Valley)                     0.000010
# Domaine Ste. Michelle 2005 Luxe Sparkling (Columbia Valley (WA))                0.000010
# Errazuriz 2010 Estate Reserva Chardonnay (Casablanca Valley)                    0.000010
# Hager Matthias 2011 Urgestein Grüner Veltliner (Niederösterreich)               0.000010
# Fazio 2008 Pietra Sacra Rosso Riserva Nero d'Avola (Erice)                      0.000010
# Name: title, Length: 92449, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Data columns (total 8 columns):
# country        101134 non-null object
# description    101134 non-null object
# points         101134 non-null int64
# price          101134 non-null float64
# province       101134 non-null object
# title          101134 non-null object
# variety        101134 non-null object
# winery         101134 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.9+ MB

# %%
df.drop(['title', 'winery'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Data columns (total 6 columns):
# country        101134 non-null object
# description    101134 non-null object
# points         101134 non-null int64
# price          101134 non-null float64
# province       101134 non-null object
# variety        101134 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.4+ MB

# %%
country_dummies = pd.get_dummies(df.country)
province_dummies = pd.get_dummies(df.province)
variety_dummies = pd.get_dummies(df.variety)
wdf = pd.concat([df,country_dummies,province_dummies, variety_dummies], axis = 1)

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Columns: 128 entries, country to Zinfandel
# dtypes: float64(1), int64(1), object(4), uint8(122)
# memory usage: 17.2+ MB

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# %%time

scores = [(analyzer.polarity_scores(i)['compound']) for i in wdf.description]
# Out:
# CPU times: user 1min 26s, sys: 661 ms, total: 1min 27s
# Wall time: 1min 28s

# %%
wdf['scores'] = scores

# %%
wdf.describe() # scatter plot over here
# Out:
#               points          price      Argentina      Australia  \
# count  101134.000000  101134.000000  101134.000000  101134.000000
# mean       88.517235      36.957492       0.034202       0.011856
# std         3.078660      43.239912       0.181749       0.108236
# min        80.000000       4.000000       0.000000       0.000000
# 25%        86.000000      18.000000       0.000000       0.000000
# 50%        88.000000      28.000000       0.000000       0.000000
# 75%        91.000000      45.000000       0.000000       0.000000
# max       100.000000    3300.000000       1.000000       1.000000
#
#              Austria          Chile         France        Germany  \
# count  101134.000000  101134.000000  101134.000000  101134.000000
# mean        0.016434       0.026994       0.166195       0.013022
# std         0.127137       0.162066       0.372258       0.113371
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                Italy    New Zealand  ...          Syrah    Tempranillo  \
# count  101134.000000  101134.000000  ...  101134.000000  101134.000000
# mean        0.136304       0.007762  ...       0.037178       0.017116
# std         0.343113       0.087760  ...       0.189200       0.129704
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.000000       0.000000  ...       0.000000       0.000000
# 50%         0.000000       0.000000  ...       0.000000       0.000000
# 75%         0.000000       0.000000  ...       0.000000       0.000000
# max         1.000000       1.000000  ...       1.000000       1.000000
#
#        Tempranillo Blend      Torrontés        Verdejo     Vermentino  \
# count      101134.000000  101134.000000  101134.000000  101134.000000
# mean            0.005695       0.002442       0.002808       0.001978
# std             0.075253       0.049360       0.052918       0.044426
# min             0.000000       0.000000       0.000000       0.000000
# 25%             0.000000       0.000000       0.000000       0.000000
# 50%             0.000000       0.000000       0.000000       0.000000
# 75%             0.000000       0.000000       0.000000       0.000000
# max             1.000000       1.000000       1.000000       1.000000
#
#             Viognier    White Blend      Zinfandel         scores
# count  101134.000000  101134.000000  101134.000000  101134.000000
# mean        0.008929       0.018302       0.026747       0.512177
# std         0.094070       0.134043       0.161343       0.372688
# min         0.000000       0.000000       0.000000      -0.928800
# 25%         0.000000       0.000000       0.000000       0.273200
# 50%         0.000000       0.000000       0.000000       0.624900
# 75%         0.000000       0.000000       0.000000       0.817600
# max         1.000000       1.000000       1.000000       0.993700
#
# [8 rows x 125 columns]

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Columns: 129 entries, country to scores
# dtypes: float64(2), int64(1), object(4), uint8(122)
# memory usage: 17.9+ MB

# %%
wdf.drop(['country', 'province', 'variety', 'description'], axis = 1, inplace = True)

# %%
wdf.head()
# Out:
#    points  price  Argentina  Australia  Austria  Chile  France  Germany  \
# 1      87   15.0          0          0        0      0       0        0
# 2      87   14.0          0          0        0      0       0        0
# 4      87   65.0          0          0        0      0       0        0
# 7      87   24.0          0          0        0      0       1        0
# 9      87   27.0          0          0        0      0       1        0
#
#    Italy  New Zealand  ...  Syrah  Tempranillo  Tempranillo Blend  Torrontés  \
# 1      0            0  ...      0            0                  0          0
# 2      0            0  ...      0            0                  0          0
# 4      0            0  ...      0            0                  0          0
# 7      0            0  ...      0            0                  0          0
# 9      0            0  ...      0            0                  0          0
#
#    Verdejo  Vermentino  Viognier  White Blend  Zinfandel  scores
# 1        0           0         0            0          0  0.6486
# 2        0           0         0            0          0 -0.1280
# 4        0           0         0            0          0  0.8176
# 7        0           0         0            0          0  0.0000
# 9        0           0         0            0          0  0.7506
#
# [5 rows x 125 columns]

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Columns: 125 entries, points to scores
# dtypes: float64(2), int64(1), uint8(122)
# memory usage: 14.9 MB

# %%
wdf.head()
# Out:
#    points  price  Argentina  Australia  Austria  Chile  France  Germany  \
# 1      87   15.0          0          0        0      0       0        0
# 2      87   14.0          0          0        0      0       0        0
# 4      87   65.0          0          0        0      0       0        0
# 7      87   24.0          0          0        0      0       1        0
# 9      87   27.0          0          0        0      0       1        0
#
#    Italy  New Zealand  ...  Syrah  Tempranillo  Tempranillo Blend  Torrontés  \
# 1      0            0  ...      0            0                  0          0
# 2      0            0  ...      0            0                  0          0
# 4      0            0  ...      0            0                  0          0
# 7      0            0  ...      0            0                  0          0
# 9      0            0  ...      0            0                  0          0
#
#    Verdejo  Vermentino  Viognier  White Blend  Zinfandel  scores
# 1        0           0         0            0          0  0.6486
# 2        0           0         0            0          0 -0.1280
# 4        0           0         0            0          0  0.8176
# 7        0           0         0            0          0  0.0000
# 9        0           0         0            0          0  0.7506
#
# [5 rows x 125 columns]

# %%
wdf.points = wdf.points.astype('int')
wdf.price = wdf.price.astype('int')

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Columns: 125 entries, points to scores
# dtypes: float64(1), int64(2), uint8(122)
# memory usage: 14.9 MB

# %%
wdf.columns.get_loc('Port')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
wdf = wdf.rename(columns={wdf.columns[99]: 'Port_B'})

# %%
wdf.columns[99]
# Out:
# 'Port_B'

# %%
print(wdf.columns[49] == wdf.columns[99])
# Out:
# True

# %%
wdf.drop(['Port_B'], axis = 1, inplace = True)

# %%
print(wdf.columns[49] == wdf.columns[99]) # sanity check
# Out:
# False

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101134 entries, 1 to 129970
# Columns: 123 entries, points to scores
# dtypes: float64(1), int64(2), uint8(120)
# memory usage: 14.7 MB

# %%
wdf.price.hist()

# %%
wdf = wdf[wdf.price <= 100] #drop some outliers for a better distribution

# %%
wdf.price.hist()

# %%
wdf.scores.hist()

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98057 entries, 1 to 129970
# Columns: 123 entries, points to scores
# dtypes: float64(1), int64(2), uint8(120)
# memory usage: 14.2 MB

# %%
wdf.points.hist() #drop some outliers here too

# %%
wdf.info()

# %%
wdf[['scores', 'points', 'price']].corr()
# Out:
#           scores    points     price
# scores  1.000000  0.310234  0.061699
# points  0.310234  1.000000  0.552673
# price   0.061699  0.552673  1.000000

# %% [markdown]
# ## No strong multicollinearity issues, looks like points is quite strongly correlated with price. Let's examine further

# %%
plt.scatter(wdf.points.iloc[0:500], wdf.price.iloc[0:500])
plt.xlabel('points')
plt.ylabel('price')
plt.title('Price vs. Points')
plt.show()
#only showing 500 samples for better visuals

# %% [markdown]
# There's definitely a slight increase in price as points increase but nothing definitive.

# %%
plt.scatter(wdf.scores.iloc[0:500], wdf.price.iloc[0:500])
plt.xlabel('score')
plt.ylabel('price')
plt.title('Price vs. Score')
plt.show()

# %% [markdown]
# Some correlation here, nothing too strong.

# %%
plt.scatter(wdf.scores.iloc[0:500], wdf.points.iloc[0:500])

# %% [markdown]
# No correlation here.

# %%
wdf.columns = wdf.columns.str.replace(' ', '_')
wdf.columns = wdf.columns.str.replace('ö', 'o')
wdf.columns = wdf.columns.str.replace('ô', 'o')
wdf.columns = wdf.columns.str.replace('Sicily_&_Sardinia', 'SicilynSardinia')
wdf.columns = wdf.columns.str.replace('ñ' , 'n')
wdf.columns = wdf.columns.str.replace('ä', 'a')
wdf.columns = wdf.columns.str.replace('è', 'n')
wdf.columns = wdf.columns.str.replace("Nero_d'Avola", "Nero_dAvola")

wdf.columns = wdf.columns.str.replace("-", "_")
wdf.columns = wdf.columns.str.replace(",", "_")

# %%
mse = []
training_mse = []
model_name = []

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import statsmodels.stats.api as sms
import patsy


outcome = 'price'
predictor = wdf.drop(['price'], axis = 1)
pred_sum = '+' .join(predictor)
formula = outcome + '~' + pred_sum
model = smf.ols(formula = formula, data=wdf).fit() 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     802.3
# Date:                Wed, 14 Aug 2019   Prob (F-statistic):               0.00
# Time:                        18:08:26   Log-Likelihood:            -3.9932e+05
# No. Observations:               98057   AIC:                         7.989e+05
# Df Residuals:                   97946   BIC:                         7.999e+05
# Df Model:                         110
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      -224.6912      1.969   -114.096      0.000    -228.551    -220.831
# points                            3.2795      0.017    190.517      0.000       3.246       3.313
# Argentina                       -20.5303      0.367    -55.914      0.000     -21.250     -19.811
# Australia                       -14.1268      0.313    -45.117      0.000     -14.741     -13.513
# Austria                         -18.1309      0.532    -34.066      0.000     -19.174     -17.088
# Chile                           -27.1521      0.407    -66.779      0.000     -27.949     -26.355
# France                          -21.7523      0.416    -52.254      0.000     -22.568     -20.936
# Germany                         -11.3579      0.449    -25.301      0.000     -12.238     -10.478
# Italy                           -19.8920      0.419    -47.442      0.000     -20.714     -19.070
# New_Zealand                     -14.8900      0.322    -46.174      0.000     -15.522     -14.258
# Portugal                        -22.1692      1.586    -13.982      0.000     -25.277     -19.062
# South_Africa                    -13.7074      0.428    -32.042      0.000     -14.546     -12.869
# Spain                           -21.2749      0.448    -47.525      0.000     -22.152     -20.398
# US                              -19.7071      0.353    -55.790      0.000     -20.399     -19.015
# Alentejano                       -4.6103      2.163     -2.132      0.033      -8.850      -0.371
# Alsace                            0.1219      0.407      0.300      0.764      -0.675       0.919
# Beaujolais                       -6.0002      1.503     -3.991      0.000      -8.947      -3.054
# Bordeaux                        -13.7619      0.388    -35.476      0.000     -14.522     -13.002
# Burgenland                       -9.6039      0.839    -11.443      0.000     -11.249      -7.959
# Burgundy                          8.0319      0.339     23.721      0.000       7.368       8.696
# California                       -1.6225      0.155    -10.484      0.000      -1.926      -1.319
# Casablanca_Valley                -2.8155      0.547     -5.146      0.000      -3.888      -1.743
# Catalonia                        -4.9935      0.507     -9.841      0.000      -5.988      -3.999
# Central_Italy                    -8.8871      0.626    -14.204      0.000     -10.113      -7.661
# Central_Spain                    -8.6144      0.648    -13.303      0.000      -9.884      -7.345
# Central_Valley                   -5.8746      0.670     -8.771      0.000      -7.187      -4.562
# Champagne                        24.6979      0.681     36.270      0.000      23.363      26.033
# Colchagua_Valley                 -6.1142      0.493    -12.399      0.000      -7.081      -5.148
# Douro                            -2.1592      2.162     -0.999      0.318      -6.397       2.079
# France_Other                     -6.4871      0.612    -10.603      0.000      -7.686      -5.288
# Galicia                          -2.2785      1.019     -2.235      0.025      -4.276      -0.281
# Kamptal                          -2.2473      0.721     -3.118      0.002      -3.660      -0.835
# Kremstal                         -4.0481      0.763     -5.302      0.000      -5.544      -2.552
# Languedoc_Roussillon             -7.5859      0.611    -12.417      0.000      -8.783      -6.388
# Lisboa                           -7.8352      2.201     -3.559      0.000     -12.150      -3.521
# Loire_Valley                     -2.1989      0.442     -4.975      0.000      -3.065      -1.333
# Lombardy                          4.8651      0.766      6.354      0.000       3.364       6.366
# Maipo_Valley                     -6.1898      0.535    -11.560      0.000      -7.239      -5.140
# Marlborough                     -14.8900      0.322    -46.174      0.000     -15.522     -14.258
# Maule_Valley                     -6.1580      0.635     -9.698      0.000      -7.403      -4.913
# Mendoza_Province                -10.6101      0.323    -32.806      0.000     -11.244      -9.976
# Mosel                            -9.9987      0.454    -22.043      0.000     -10.888      -9.110
# New_York                         -5.6759      0.276    -20.551      0.000      -6.217      -5.135
# Niederosterreich                 -6.9332      0.674    -10.283      0.000      -8.255      -5.612
# Northeastern_Italy               -1.6094      0.496     -3.242      0.001      -2.582      -0.636
# Northern_Spain                   -5.3885      0.454    -11.858      0.000      -6.279      -4.498
# Oregon                           -3.3709      0.224    -15.073      0.000      -3.809      -2.933
# Other                            -9.9202      0.476    -20.821      0.000     -10.854      -8.986
# Piedmont                         -0.2405      0.642     -0.375      0.708      -1.498       1.017
# Provence                         -4.7732      0.505     -9.457      0.000      -5.762      -3.784
# Rheingau                         -1.3592      0.615     -2.208      0.027      -2.566      -0.153
# Rhone_Valley                     -1.9170      0.529     -3.627      0.000      -2.953      -0.881
# SicilynSardinia                  -6.3660      0.515    -12.355      0.000      -7.376      -5.356
# South_Australia                 -14.1268      0.313    -45.117      0.000     -14.741     -13.513
# Southern_Italy                   -6.5948      0.773     -8.531      0.000      -8.110      -5.080
# Southwest_France                -11.8798      0.488    -24.332      0.000     -12.837     -10.923
# Stellenbosch                    -13.7074      0.428    -32.042      0.000     -14.546     -12.869
# Tejo                             -6.7237      2.165     -3.106      0.002     -10.967      -2.481
# Tuscany                          -3.2317      0.330     -9.796      0.000      -3.878      -2.585
# Veneto                            2.1723      0.520      4.175      0.000       1.152       3.192
# Virginia                         -1.2932      0.470     -2.751      0.006      -2.215      -0.372
# Wachau                            4.7015      0.758      6.206      0.000       3.217       6.186
# Washington                       -7.7446      0.194    -39.956      0.000      -8.125      -7.365
# Aglianico                        -2.5289      2.139     -1.182      0.237      -6.722       1.664
# Albarino                        -16.4434      2.110     -7.792      0.000     -20.579     -12.307
# Barbera                         -13.3018      1.932     -6.886      0.000     -17.088      -9.515
# Blaufrankisch                   -10.7862      2.330     -4.630      0.000     -15.352      -6.220
# Bordeaux_style_Red_Blend          2.8197      1.819      1.550      0.121      -0.746       6.385
# Bordeaux_style_White_Blend       -2.7963      1.903     -1.470      0.142      -6.525       0.933
# Cabernet_Franc                   -4.8796      1.842     -2.648      0.008      -8.491      -1.268
# Cabernet_Sauvignon                2.0898      1.800      1.161      0.246      -1.438       5.617
# Carmennre                        -6.0751      1.954     -3.108      0.002      -9.906      -2.244
# Champagne_Blend                 -10.2840      1.945     -5.286      0.000     -14.097      -6.471
# Chardonnay                       -9.7911      1.799     -5.442      0.000     -13.317      -6.265
# Chenin_Blanc                    -14.7135      1.947     -7.557      0.000     -18.529     -10.898
# Corvina__Rondinella__Molinara    -4.4319      1.989     -2.228      0.026      -8.330      -0.533
# Gamay                           -13.4829      2.436     -5.535      0.000     -18.258      -8.708
# Garganega                       -21.9305      2.111    -10.389      0.000     -26.068     -17.793
# Garnacha                         -9.9992      2.008     -4.980      0.000     -13.935      -6.063
# Gewürztraminer                  -13.4907      1.867     -7.226      0.000     -17.150      -9.832
# Glera                           -20.9139      1.964    -10.647      0.000     -24.764     -17.064
# Grenache                         -6.3194      1.880     -3.361      0.001     -10.004      -2.635
# Grüner_Veltliner                -18.7554      1.924     -9.749      0.000     -22.526     -14.985
# Malbec                           -4.2545      1.828     -2.328      0.020      -7.837      -0.672
# Melon                           -21.1070      2.060    -10.248      0.000     -25.144     -17.070
# Meritage                         -3.1846      2.006     -1.588      0.112      -7.116       0.747
# Merlot                           -6.8915      1.813     -3.800      0.000     -10.446      -3.337
# Montepulciano                    -4.5954      2.156     -2.131      0.033      -8.822      -0.369
# Moscato                         -15.2328      2.001     -7.614      0.000     -19.154     -11.312
# Mourvndre                        -6.6421      2.040     -3.257      0.001     -10.640      -2.645
# Nebbiolo                          7.0725      1.940      3.645      0.000       3.270      10.875
# Nero_dAvola                     -10.3306      2.034     -5.078      0.000     -14.318      -6.344
# Petit_Verdot                     -0.5253      2.011     -0.261      0.794      -4.466       3.416
# Petite_Sirah                     -9.0036      1.867     -4.822      0.000     -12.663      -5.344
# Pinot_Blanc                     -17.7320      1.952     -9.086      0.000     -21.557     -13.907
# Pinot_Grigio                    -16.6223      1.869     -8.892      0.000     -20.286     -12.958
# Pinot_Gris                      -16.8781      1.842     -9.162      0.000     -20.489     -13.267
# Pinot_Noir                       -0.8481      1.798     -0.472      0.637      -4.373       2.677
# Portuguese_Red                  -13.1927      2.019     -6.535      0.000     -17.149      -9.236
# Portuguese_White                -14.5383      2.064     -7.043      0.000     -18.584     -10.492
# Primitivo                        -8.9024      2.097     -4.245      0.000     -13.013      -4.792
# Prosecco                        -18.1987      2.135     -8.523      0.000     -22.384     -14.014
# Red_Blend                        -5.3624      1.804     -2.972      0.003      -8.898      -1.826
# Rhone_style_Red_Blend            -7.7511      1.845     -4.201      0.000     -11.367      -4.135
# Rhone_style_White_Blend          -9.2848      1.939     -4.787      0.000     -13.086      -5.484
# Riesling                        -15.9676      1.820     -8.772      0.000     -19.535     -12.400
# Rosé                            -13.0220      1.819     -7.158      0.000     -16.588      -9.456
# Sangiovese                       -1.1455      1.834     -0.624      0.532      -4.741       2.450
# Sangiovese_Grosso                10.8024      1.921      5.623      0.000       7.037      14.568
# Sauvignon                       -13.4801      2.032     -6.634      0.000     -17.462      -9.498
# Sauvignon_Blanc                 -14.0048      1.809     -7.741      0.000     -17.551     -10.459
# Shiraz                           -1.0353      1.945     -0.532      0.595      -4.848       2.777
# Sparkling_Blend                 -10.2117      1.832     -5.574      0.000     -13.803      -6.621
# Syrah                            -4.2501      1.808     -2.350      0.019      -7.794      -0.706
# Tempranillo                      -6.8246      1.860     -3.670      0.000     -10.469      -3.180
# Tempranillo_Blend                -5.2578      1.946     -2.702      0.007      -9.071      -1.444
# Torrontés                       -10.0889      2.051     -4.919      0.000     -14.109      -6.069
# Verdejo                         -13.8879      2.031     -6.839      0.000     -17.868      -9.908
# Vermentino                      -13.7966      2.068     -6.673      0.000     -17.849      -9.744
# Viognier                        -11.5030      1.855     -6.203      0.000     -15.138      -7.868
# White_Blend                     -11.2392      1.827     -6.152      0.000     -14.820      -7.658
# Zinfandel                        -9.5788      1.813     -5.283      0.000     -13.132      -6.025
# scores                           -5.1675      0.132    -39.096      0.000      -5.427      -4.908
# ==============================================================================
# Omnibus:                    18168.669   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37513.903
# Skew:                           1.106   Prob(JB):                         0.00
# Kurtosis:                       5.071   Cond. No.                     4.64e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.56e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y = wdf.price
X = wdf.drop(['price'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 100)

# %%
X_train.shape, X_test.shape, X.shape, y_train.shape
# Out:
# ((68639, 122), (29418, 122), (98057, 122), (68639,))

# %%
y_pred = model.predict(X_test)

# %%
mse.append(mean_squared_error(y_test,y_pred))
model_name.append('Multiple Linear Regression')

# %%
y_trainpred = model.predict(X_train)

# %%
training_mse.append(mean_squared_error(y_train, y_trainpred))

# %%
mse, model_name, training_mse
# Out:
# ([202.63795788939714], ['Multiple Linear Regression'], [201.2847315100795])

# %%
def scatterFirst500(y_pred, y_test, model):
    y_preds = y_pred.tolist()
    y_p = []
    for i in list(range(0,500)):
        y_p.append(y_preds[i])
    fig, ax = plt.subplots()
    ax.scatter(y_test[0:500], y_p, edgecolors=(0, 0, 0))
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')
    ax.set_title("True values vs Predicted: " + model)
    plt.legend()
    plt.show()

# %%
scatterFirst500(y_pred, y_test, 'Multiple Linear Regression Testing')
# Out:
# No handles with labels found to put in legend.

# %%
scatterFirst500(y_train, y_trainpred, 'Multiple Linear Regression Training')
# Out:
# No handles with labels found to put in legend.

# %%
x_gb = xgb.XGBRegressor()
x_gb.fit(X_train,y_train)
x_gbypred = x_gb.predict(X_test)
x_gbypredtrain = x_gb.predict(X_train)
mse.append(mean_squared_error(y_test, x_gbypred))
training_mse.append(mean_squared_error(y_train, x_gbypredtrain))
model_name.append('XGB_MSE')
scatterFirst500(x_gbypred, y_test, 'XGB Testing')
scatterFirst500(x_gbypredtrain, y_train, 'XGB Training')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
mse, model_name, training_mse
# Out:
# ([202.63795788939714, 193.26265703625566],
#  ['Multiple Linear Regression', 'XGB_MSE'],
#  [201.2847315100795, 191.57609026543238])

# %%
X_train.shape, X_test.shape, y_train.shape , y_test.shape #sanity check
# Out:
# ((68639, 122), (29418, 122), (68639,), (29418,))

# %%
def twoLayerNeuralNet(activation1, activation2, opt, X_train, y_train, X_test, y_test):
    model = Sequential()
    model.add(Dense(24, activation = activation1, input_shape = (122,)))
    model.add(Dense(16, activation= activation2))
    model.add(Dense(1))
    model.compile(loss='mse',
              optimizer= opt,
              metrics=['mse']) ##MSE
    callbacks = [EarlyStopping(monitor='val_mean_squared_error', patience=4),
             ModelCheckpoint(filepath='best_model.h5', monitor='val_mean_squared_error', save_best_only=True)]
    history = model.fit(X_train, 
              y_train,
              epochs = 150,
              batch_size = 5,
              verbose = 0,
              validation_data= (X_test, y_test), callbacks = callbacks)
    history_dict = history.history
    training_predictions = model.predict(X_train)
    y_pred = model.predict(X_test)
    history_dict['y_pred'] = y_pred
    history_dict['training_prediction'] = training_predictions
    return history_dict

# %%
a_lin_lin = twoLayerNeuralNet(activation1='linear', activation2='linear', opt=optimizers.Adam(lr=0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
aLinLinScatter = scatterFirst500(a_lin_lin['y_pred'], y_test, 'Adam Linear Linear')
# Out:
# No handles with labels found to put in legend.

# %%
aLinLinScatter = scatterFirst500(a_lin_lin['training_prediction'], y_test, 'Adam Linear Linear')
# Out:
# No handles with labels found to put in legend.

# %%
a_lin_rel = twoLayerNeuralNet(activation1='linear', activation2='relu', opt=optimizers.Adam(lr=0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
alinRelScatter = scatterFirst500(a_lin_rel['y_pred'], y_test, 'Adam Linear Relu')
# Out:
# No handles with labels found to put in legend.

# %%
alinRelScatter = scatterFirst500(a_lin_rel['training_prediction'], y_test, 'Adam Linear Relu')
# Out:
# No handles with labels found to put in legend.

# %%
a_rel_lin = twoLayerNeuralNet(activation1='relu', activation2='linear', opt=optimizers.Adam(lr=0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
aRelLinScatter = scatterFirst500(a_rel_lin['y_pred'], y_test, 'Adam Linear Linear')
# Out:
# No handles with labels found to put in legend.

# %%
aRelLinScatter = scatterFirst500(a_rel_lin['training_prediction'], y_test, 'Adam Linear Linear')
# Out:
# No handles with labels found to put in legend.

# %%
a_rel_rel = twoLayerNeuralNet(activation1='relu', activation2='relu', opt=optimizers.Adam(lr=0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
aRelRelScatter = scatterFirst500(a_rel_rel['y_pred'], y_test, 'Adam Relu Relu')
# Out:
# No handles with labels found to put in legend.

# %%
aRelRelScatter = scatterFirst500(a_rel_rel['training_prediction'], y_test, 'Adam Relu Relu')
# Out:
# No handles with labels found to put in legend.

# %%
r_lin_lin = twoLayerNeuralNet(activation1='linear', activation2='linear', opt=optimizers.RMSprop(0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
rLinLinScatter = scatterFirst500(r_lin_lin['y_pred'], y_test, 'Adam Linear Linear')
# Out:
# No handles with labels found to put in legend.

# %%
rLinLinScatter = scatterFirst500(r_lin_lin['training_prediction'], y_test, 'Adam Linear Linear')
# Out:
# No handles with labels found to put in legend.

# %%
r_lin_rel = twoLayerNeuralNet(activation1='linear', activation2='relu', opt=optimizers.RMSprop(0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
rLinRelScatter = scatterFirst500(r_lin_rel['y_pred'], y_test, 'RMS Linear Relu')
# Out:
# No handles with labels found to put in legend.

# %%
rLinRelScatter = scatterFirst500(r_lin_rel['training_prediction'], y_test, 'RMS Linear Relu')
# Out:
# No handles with labels found to put in legend.

# %%
r_rel_lin = twoLayerNeuralNet(activation1='relu', activation2='linear', opt=optimizers.RMSprop(0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
rRelLin = scatterFirst500(r_rel_lin['y_pred'], y_test, 'RMS Relu Linear')
# Out:
# No handles with labels found to put in legend.

# %%
rRelLin = scatterFirst500(r_rel_lin['training_prediction'], y_test, 'RMS Relu Linear')
# Out:
# No handles with labels found to put in legend.

# %%
r_rel_relu = twoLayerNeuralNet(activation1='relu', activation2='relu', opt=optimizers.RMSprop(0.0001), X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
rReluReluScatter = scatterFirst500(r_rel_relu['y_pred'], y_test, 'RMS Relu Relu')
# Out:
# No handles with labels found to put in legend.

# %%
rReluReluScatter = scatterFirst500(r_rel_relu['training_prediction'], y_test, 'RMS Relu Relu')
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(20,10))
plt.title('Value Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.plot(a_lin_lin['val_mean_squared_error'], label = 'Adam-lin-lin')
plt.plot(a_lin_rel['val_mean_squared_error'], label = 'Adam-lin-relu')
plt.plot(a_rel_lin['val_mean_squared_error'], label = 'Adam-relu-lin')
plt.plot(a_rel_rel['val_mean_squared_error'], label = 'Adam-relu-relu')

plt.plot(r_lin_lin['val_mean_squared_error'], label = 'RMS-lin-lin')
plt.plot(r_lin_rel['val_mean_squared_error'], label = 'RMS-lin-relu')
plt.plot(r_rel_lin['val_mean_squared_error'], label = 'RMS-relu-lin')
plt.plot(r_rel_relu['val_mean_squared_error'], label = 'RMS-relu-relu')
plt.legend(prop = {'size' : 20})
plt.show()

# %%
def min_value(list):
    min = list[0]
    for i in list:
        if i < min:
            min = i
    return min

#testing mean squared errors for Adam optimizers
ALLmin = min_value(a_lin_lin['val_mean_squared_error'])
ALRmin = min_value(a_lin_rel['val_mean_squared_error'])
ARLmin = min_value(a_rel_lin['val_mean_squared_error'])
ARRmin = min_value(a_rel_rel['val_mean_squared_error'])


#training mean squared errors for Adam optimizer
TALLmin = min_value(a_lin_lin['mean_squared_error'])
TALRmin = min_value(a_lin_rel['mean_squared_error'])
TARLmin = min_value(a_rel_lin['mean_squared_error'])
TARRmin = min_value(a_rel_rel['mean_squared_error'])


#testing mean squared errors for RMS optimizers
RLL = min_value(r_lin_lin['val_mean_squared_error'])
RLR = min_value(r_lin_rel['val_mean_squared_error'])
RRL = min_value(r_rel_lin['val_mean_squared_error'])
RRR = min_value(r_rel_relu['val_mean_squared_error'])


#training mean squared errors for RMS optimizer
TRLL = min_value(r_lin_lin['mean_squared_error'])
TRLR = min_value(r_lin_rel['mean_squared_error'])
TRRL = min_value(r_rel_lin['mean_squared_error'])
TRRR = min_value(r_rel_relu['mean_squared_error'])


fig = plt.figure(figsize=(10,10))


tmin = [TALLmin, TALRmin, TARLmin, TARRmin, TRLL, TRLR, TRRL, TRRR]
mins = [ALLmin, ALRmin, ARLmin, ARRmin,RLL,RLR,RRL,RRR]

plt.title('Two Layer Mean Squared Error')
plt.xlabel('Model')
plt.ylabel('MSE')
labels = ['A-Lin-Lin', 'A-Lin-Relu', 'A-Relu-Lin', 'A-Relu-Relu', 'R-Lin-Lin', 'R-Lin-Relu', 'R-Relu-Lin', 'R-Relu-Relu']

plt.bar(labels, mins)
for i in list(range(0,8)):
    mse.append(mins[i])
    training_mse.append(tmin[i])
    model_name.append(labels[i])
# Out:
# <BarContainer object of 8 artists>

# %%
model_name, mse, training_mse
# Out:
# (['Multiple Linear Regression',
#   'XGB_MSE',
#   'A-Lin-Lin',
#   'A-Lin-Relu',
#   'A-Relu-Lin',
#   'A-Relu-Relu',
#   'R-Lin-Lin',
#   'R-Lin-Relu',
#   'R-Relu-Lin',
#   'R-Relu-Relu'],
#  [202.63795788939714,
#   193.26265703625566,
#   204.85545384705583,
#   202.21423604096276,
#   199.10927759805182,
#   206.27483628356438,
#   220.65875040829988,
#   211.21218533500206,
#   194.19932871323707,
#   215.81016069663212],
#  [201.2847315100795,
#   191.57609026543238,
#   206.47705138945548,
#   202.85951626811072,
#   200.43824842598394,
#   205.97064950726877,
#   217.92876405235486,
#   209.36401256398705,
#   192.9660932123075,
#   213.70183968676346])

# %% [markdown]
# Currently, the XGB model reported the best MSE with the RMS Relu-Lin close behind. Let's see if adding layers improve the current MSE.

# %%
model_name[-2]
# Out:
# 'R-Relu-Lin'

# %% [markdown]
# ### Keep the input and first layer the same as well as the optimizer and add a second layer

# %%
opt=optimizers.RMSprop(0.0001)
threeLayer = Sequential()
threeLayer.add((Dense(24, activation = 'relu', input_shape = (122,))))
threeLayer.add(Dense(16, activation = 'relu'))
threeLayer.add(Dense(16, activation = 'linear'))
threeLayer.add(Dense(1))
threeLayer.compile(loss='mse',
              optimizer= opt,
              metrics=['mse'])
callbacks = [EarlyStopping(monitor='val_mean_squared_error', patience=4),
             ModelCheckpoint(filepath='best_model.h5', monitor='val_mean_squared_error', save_best_only=True)]
history = threeLayer.fit(X_train, 
              y_train,
              epochs = 150,
              batch_size = 5,
              validation_data= (X_test, y_test), callbacks = callbacks, verbose = 0)
history1_dict = history.history
predictions = threeLayer.predict(X_train)
y_pred = threeLayer.predict(X_test)
history1_dict['y_pred'] = y_pred
history1_dict['tpredictions'] = predictions

mse.append(min_value(history1_dict['val_mean_squared_error']))
model_name.append('R-Relu-Relu-Lin')
training_mse.append(min_value(history1_dict['mean_squared_error']))

# %%
threeLayer2 = Sequential()
threeLayer2.add((Dense(24, activation = 'relu', input_shape = (122,))))
threeLayer2.add(Dense(16, activation = 'linear'))
threeLayer2.add(Dense(16, activation = 'linear'))
threeLayer2.add(Dense(1))
threeLayer2.compile(loss='mse',
              optimizer= opt,
              metrics=['mse'])
callbacks = [EarlyStopping(monitor='val_mean_squared_error', patience=4),
             ModelCheckpoint(filepath='best_model.h5', monitor='val_mean_squared_error', save_best_only=True)]
history = threeLayer2.fit(X_train, 
              y_train,
              epochs = 150,
              batch_size = 5,
              validation_data= (X_test, y_test), callbacks = callbacks, verbose = 0)
history2_dict = history.history
y_pred = threeLayer2.predict(X_test)
predictions = threeLayer2.predict(X_train)
history2_dict['y_pred'] = y_pred
history2_dict['tpredictions'] = predictions
mse.append(min_value(history2_dict['val_mean_squared_error']))
model_name.append('R-Relu-Linear-Linear')
training_mse.append(min_value(history2_dict['mean_squared_error']))

# %%
plt.figure(figsize=(20,10))
plt.title('Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.plot(history1_dict['val_mean_squared_error'], label = 'Relu-Relu-Linear')
plt.plot(history2_dict['val_mean_squared_error'], label = 'Relu-Linear-Linear')
plt.legend(prop = {'size' : 20})
plt.show()

# %%
model_name, mse, training_mse
# Out:
# (['Multiple Linear Regression',
#   'XGB_MSE',
#   'A-Lin-Lin',
#   'A-Lin-Relu',
#   'A-Relu-Lin',
#   'A-Relu-Relu',
#   'R-Lin-Lin',
#   'R-Lin-Relu',
#   'R-Relu-Lin',
#   'R-Relu-Relu',
#   'R-Relu-Relu-Lin',
#   'R-Relu-Linear-Linear'],
#  [202.63795788939714,
#   193.26265703625566,
#   204.85545384705583,
#   202.21423604096276,
#   199.10927759805182,
#   206.27483628356438,
#   220.65875040829988,
#   211.21218533500206,
#   194.19932871323707,
#   215.81016069663212,
#   194.64269020961575,
#   209.3334545291283],
#  [201.2847315100795,
#   191.57609026543238,
#   206.47705138945548,
#   202.85951626811072,
#   200.43824842598394,
#   205.97064950726877,
#   217.92876405235486,
#   209.36401256398705,
#   192.9660932123075,
#   213.70183968676346,
#   195.90375214091173,
#   208.32593839838833])

# %% [markdown]
# #### Just for kicks, here's a visual on what our best performing 3 layer neural network looks like

# %%
ann_viz(r_rel_lin, title="My Neural Network")

# %% [markdown]
#  <img src='2network.jpg'>

# %% [markdown]
# ## No improvement when adding layers, transfer the model performance metrics into a dataframe for better viewing

# %%
Model_performance = pd.DataFrame([])
Model_performance['Model_Name'] = model_name
Model_performance['Mean_Squared_Error'] = mse
Model_performance['Training_MSE'] = training_mse

# %%
Model_performance
# Out:
#                     Model_Name  Mean_Squared_Error  Training_MSE
# 0   Multiple Linear Regression          202.637958    201.284732
# 1                      XGB_MSE          193.262657    191.576090
# 2                    A-Lin-Lin          204.855454    206.477051
# 3                   A-Lin-Relu          202.214236    202.859516
# 4                   A-Relu-Lin          199.109278    200.438248
# 5                  A-Relu-Relu          206.274836    205.970650
# 6                    R-Lin-Lin          220.658750    217.928764
# 7                   R-Lin-Relu          211.212185    209.364013
# 8                   R-Relu-Lin          194.199329    192.966093
# 9                  R-Relu-Relu          215.810161    213.701840
# 10             R-Relu-Relu-Lin          194.642690    195.903752
# 11        R-Relu-Linear-Linear          209.333455    208.325938

# %% [markdown]
# ## The XGB model performed the best of all of our models. Now time for a live simulation to see how the model performs on the spot.

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98057 entries, 1 to 129970
# Columns: 123 entries, points to scores
# dtypes: float64(1), int64(2), uint8(120)
# memory usage: 14.2 MB

# %%
r = random.randint(0,98057)
r2 = r + 10

# %%
wines10 = wdf.iloc[r:r2]

# %%
wines10
# Out:
#         points  price  Argentina  Australia  Austria  Chile  France  Germany  \
# 115294      89     32          0          0        0      0       0        0
# 115295      89     55          0          0        0      0       0        0
# 115299      89     17          0          0        0      0       1        0
# 115300      89     26          0          0        0      0       1        0
# 115302      89     27          0          0        0      0       1        0
# 115303      89     25          0          0        0      0       0        0
# 115304      89     50          0          0        0      0       0        0
# 115305      89     34          0          0        0      0       0        0
# 115306      94     52          0          0        0      0       0        0
# 115307      94     44          0          0        0      0       0        0
#
#         Italy  New_Zealand  ...  Syrah  Tempranillo  Tempranillo_Blend  \
# 115294      0            0  ...      0            0                  0
# 115295      0            0  ...      0            0                  0
# 115299      0            0  ...      0            0                  0
# 115300      0            0  ...      0            0                  0
# 115302      0            0  ...      0            0                  0
# 115303      0            0  ...      0            0                  0
# 115304      0            0  ...      0            0                  0
# 115305      0            0  ...      0            0                  0
# 115306      0            0  ...      0            0                  0
# 115307      0            0  ...      0            0                  0
#
#         Torrontés  Verdejo  Vermentino  Viognier  White_Blend  Zinfandel  \
# 115294          0        0           0         0            0          0
# 115295          0        0           0         0            0          0
# 115299          0        0           0         0            0          0
# 115300          0        0           0         0            0          0
# 115302          0        0           0         0            0          0
# 115303          0        0           0         0            0          0
# 115304          0        0           0         0            0          0
# 115305          0        0           0         0            0          0
# 115306          0        0           0         0            0          0
# 115307          0        0           0         0            0          0
#
#         scores
# 115294  0.1513
# 115295  0.8271
# 115299  0.7430
# 115300  0.8519
# 115302  0.6124
# 115303  0.7717
# 115304  0.1779
# 115305  0.6705
# 115306  0.5267
# 115307  0.7964
#
# [10 rows x 123 columns]

# %%
actualPrice = wines10.price
wines10 = wines10.drop('price', axis = 1)

# %%
y_pred = x_gb.predict(wines10)

# %%
prices = pd.DataFrame([])

# %%
prices['Actual'] = actualPrice
prices['Predicted'] = y_pred

# %%
prices
# Out:
#         Actual  Predicted
# 115294      32  31.155443
# 115295      55  39.198372
# 115299      17  27.154383
# 115300      26  24.545677
# 115302      27  25.852600
# 115303      25  28.884472
# 115304      50  44.260384
# 115305      34  27.754457
# 115306      52  54.852261
# 115307      44  54.582882

# %%
N = 10
ind = np.arange(N) 
width = 0.35    
fig = plt.figure(figsize=(10,10)) # Create matplotlib figure



width = 0.4
plt.title('Actual vs Predicted Prices')
plt.ylabel('Price')
plt.bar(ind, prices.Actual, width, label='Actual')
plt.bar(ind + width, prices.Predicted, width,label='Predicted')
plt.legend()
plt.xticks(ind + width, ('Wine1', 'Wine2', 'Wine3', 'Wine4', 'Wine5', 'Wine6', 'Wine7', 'Wine8', 'Wine9', 'Wine10'))

plt.show()
